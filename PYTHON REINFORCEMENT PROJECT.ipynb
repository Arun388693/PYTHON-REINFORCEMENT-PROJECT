# %%
# Importing Libraries for this project

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Understanding

# %%
# Read the csv file

laptop = pd.read_csv('/content/laptopData.csv')
laptop
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook   65.4
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
laptop.head(10)
# Out:
#    Unnamed: 0 Company   TypeName Inches                    ScreenResolution  \
# 0         0.0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1         1.0   Apple  Ultrabook   13.3                            1440x900
# 2         2.0      HP   Notebook   15.6                   Full HD 1920x1080
# 3         3.0   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4         4.0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 5         5.0    Acer   Notebook   15.6                            1366x768
# 6         6.0   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 7         7.0   Apple  Ultrabook   13.3                            1440x900
# 8         8.0    Asus  Ultrabook     14                   Full HD 1920x1080
# 9         9.0    Acer  Ultrabook     14         IPS Panel Full HD 1920x1080
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# ...

# %%
laptop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1273 non-null   float64
#  1   Company           1273 non-null   object
#  2   TypeName          1253 non-null   object
#  3   Inches            1220 non-null   object
#  4   ScreenResolution  1273 non-null   object
#  5   Cpu               1273 non-null   object
#  6   Ram               1259 non-null   object
#  7   Memory            1273 non-null   object
#  8   Gpu               1273 non-null   object
#  9   OpSys             1273 non-null   object
#  10  Weight            1259 non-null   object
#  11  Price             1273 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 122.3+ KB

# %%
laptop.columns
# Out:
# Index(['Unnamed: 0', 'Company', 'TypeName', 'Inches', 'ScreenResolution',
#        'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %%
laptop.shape
# Out:
# (1303, 12)

# %% [markdown]
# **Data Description**

# %%
laptop.describe()
# Out:
#         Unnamed: 0          Price
# count  1273.000000    1273.000000
# mean    652.674784   59955.814073
# std     376.493027   37332.251005
# min       0.000000    9270.720000
# 25%     327.000000   31914.720000
# 50%     652.000000   52161.120000
# 75%     980.000000   79333.387200
# max    1302.000000  324954.720000

# %% [markdown]
# ## Data Cleaning

# %%
# The feature - 'Unnamed: 0' is just a row index.
# So the colunm 'Unnamed: 0' is dropped.

LaptopPrice_df = laptop.drop("Unnamed: 0", axis=1)
LaptopPrice_df.head(10)
# Out:
#   Company   TypeName Inches                    ScreenResolution  \
# 0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook   13.3                            1440x900
# 2      HP   Notebook   15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 5    Acer   Notebook   15.6                            1366x768
# 6   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 7   Apple  Ultrabook   13.3                            1440x900
# 8    Asus  Ultrabook     14                   Full HD 1920x1080
# 9    Acer  Ultrabook     14         IPS Panel Full HD 1920x1080
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# ...

# %%
# Check the unique values for Inches column

LaptopPrice_df['Inches'].unique()
# Out:
# array(['13.3', '15.6', '15.4', '14', '12', nan, '17.3', '13.5', '12.5',
#        '13', '18.4', '13.9', '11.6', '25.6', '35.6', '12.3', '27.3', '24',
#        '33.5', '?', '31.6', '17', '15', '14.1', '11.3', '88.1', '21.8',
#        '10.1', '75.7', '8.4', '2.1', '111.8', '89.2', '65.4'],
#       dtype=object)

# %%
# Fix the unique values

LaptopPrice_df['Inches']=LaptopPrice_df['Inches'].str.replace('?', '',regex = False)

# %%
LaptopPrice_df['Inches']=pd.to_numeric(LaptopPrice_df['Inches'], errors='coerce')

# %%
# Fix the unique values for Ram column

LaptopPrice_df['Ram']=LaptopPrice_df['Ram'].str.replace('GB', '')

# %%
LaptopPrice_df['Ram']=pd.to_numeric(LaptopPrice_df['Ram'], errors='coerce')

# %%
# Fix the unique values for memory column

LaptopPrice_df['Memory']=LaptopPrice_df['Memory'].str.replace('?','', regex=False)

# %%
# Fix the unique values for weight column

LaptopPrice_df['Weight']=LaptopPrice_df['Weight'].str.replace('kg', '')

# %%
LaptopPrice_df['Weight']=pd.to_numeric(LaptopPrice_df['Weight'], errors='coerce')
LaptopPrice_df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    65.4
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
# Check null values

LaptopPrice_df.isnull().sum()
# Out:
# Company             30
# TypeName            50
# Inches              84
# ScreenResolution    30
# Cpu                 30
# Ram                 44
# Memory              30
# Gpu                 30
# OpSys               30
# Weight              46
# Price               30
# dtype: int64

# %%
LaptopPrice_df.isnull().sum().sum()
# Out:
# np.int64(434)

# %%
# Numeric columns - fill with median
LaptopPrice_df['Inches']=LaptopPrice_df['Inches'].fillna(LaptopPrice_df['Inches'].median())
LaptopPrice_df['Ram']=LaptopPrice_df['Ram'].fillna(LaptopPrice_df['Ram'].median())
LaptopPrice_df['Weight']=LaptopPrice_df['Weight'].fillna(LaptopPrice_df['Weight'].median())
LaptopPrice_df['Price']=LaptopPrice_df['Price'].fillna(LaptopPrice_df['Price'].median())

# %%
# Text/Mixed columns → fill with mode
LaptopPrice_df['Cpu']=LaptopPrice_df['Cpu'].fillna(LaptopPrice_df['Cpu'].mode()[0])
LaptopPrice_df['ScreenResolution']=LaptopPrice_df['ScreenResolution'].fillna(LaptopPrice_df['ScreenResolution'].mode()[0])
LaptopPrice_df['Memory']=LaptopPrice_df['Memory'].fillna(LaptopPrice_df['Memory'].mode()[0])
LaptopPrice_df['Company']=LaptopPrice_df['Company'].fillna(LaptopPrice_df['Company'].mode()[0])
LaptopPrice_df['TypeName']=LaptopPrice_df['TypeName'].fillna(LaptopPrice_df['TypeName'].mode()[0])
LaptopPrice_df['Gpu']=LaptopPrice_df['Gpu'].fillna(LaptopPrice_df['Gpu'].mode()[0])
LaptopPrice_df['OpSys']=LaptopPrice_df['OpSys'].fillna(LaptopPrice_df['OpSys'].mode()[0])

# %%
LaptopPrice_df.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
LaptopPrice_df.shape
# Out:
# (1303, 11)

# %%
# Find Duplicates
LaptopPrice_df.duplicated().sum()
# Out:
# np.int64(57)

# %%
LaptopPrice_df=LaptopPrice_df.drop_duplicates()

# %%
LaptopPrice_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
LaptopPrice_df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1270  Lenovo  2 in 1 Convertible    14.0
# 1271  Lenovo  2 in 1 Convertible    13.3
# 1272  Lenovo            Notebook    14.0
# 1273      HP            Notebook    15.6
# 1300  Lenovo            Notebook    65.4
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1270   IPS Panel Full HD / Touchscreen 1920x1080
# 1271  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
# Deal with ScreenResolution column we should extract Touchscreen and Ips and XxY resolution
LaptopPrice_df["Touchscreen"] = LaptopPrice_df["ScreenResolution"].apply(lambda x: 1 if "Touchscreen" in x else 0)
LaptopPrice_df["Ips"] = LaptopPrice_df["ScreenResolution"].apply(lambda x: 1 if "IPS" in x else 0)
LaptopPrice_df[["X_resolution", "Y_resolution"]] = LaptopPrice_df["ScreenResolution"].str.extract(r'(\d+)x(\d+)').astype(int)
LaptopPrice_df.drop(columns=["ScreenResolution"], inplace=True)
LaptopPrice_df.head()
# Out:
#   Company   TypeName  Inches                         Cpu   Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz   8.0
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz   8.0
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz   8.0
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz  16.0
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz   8.0
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips  X_resolution  Y_resolution
# 0   71378.6832            0    1          2560          1600
# ...

# %%
LaptopPrice_df[['CPU', 'Frequency']] = LaptopPrice_df['Cpu'].str.rsplit(' ', n=1, expand= True)

# %%
LaptopPrice_df[['Storage', 'StorageCapacity']] = LaptopPrice_df['Memory'].str.rsplit(' ', n=1, expand= True)

# %%
LaptopPrice_df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1270  Lenovo  2 in 1 Convertible    14.0
# 1271  Lenovo  2 in 1 Convertible    13.3
# 1272  Lenovo            Notebook    14.0
# 1273      HP            Notebook    15.6
# 1300  Lenovo            Notebook    65.4
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8.0            128GB SSD
# 1                     Intel Core i5 1.8GHz   8.0  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8.0            256GB SSD
# 3                     Intel Core i7 2.7GHz  16.0            512GB SSD
# 4                     Intel Core i5 3.1GHz   8.0            256GB SSD
# ...

# %%
LaptopPrice_df['Frequency']=LaptopPrice_df['Frequency'].str.replace('GHz', ''). astype(float)
LaptopPrice_df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1270  Lenovo  2 in 1 Convertible    14.0
# 1271  Lenovo  2 in 1 Convertible    13.3
# 1272  Lenovo            Notebook    14.0
# 1273      HP            Notebook    15.6
# 1300  Lenovo            Notebook    65.4
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8.0            128GB SSD
# 1                     Intel Core i5 1.8GHz   8.0  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8.0            256GB SSD
# 3                     Intel Core i7 2.7GHz  16.0            512GB SSD
# 4                     Intel Core i5 3.1GHz   8.0            256GB SSD
# ...

# %%
# Take the most common companies and label the rest as 'Other'
valid_companies = ["Apple", "Dell", "HP", "Lenovo", "Asus", "Acer", "MSI", "Toshiba"]
LaptopPrice_df["Company"] = LaptopPrice_df["Company"].where(LaptopPrice_df["Company"].isin(valid_companies), "Other")
LaptopPrice_df["Company"].value_counts()
# Out:
# Company
# Lenovo     284
# Dell       281
# HP         260
# Asus       149
# Acer       101
# MSI         53
# Other       50
# Toshiba     47
# Apple       21
# Name: count, dtype: int64

# %% [markdown]
# ### Decriptive Analysis

# %%
LaptopPrice_df.describe()
# Out:
#             Inches          Ram       Weight          Price  Touchscreen  \
# count  1246.000000  1246.000000  1246.000000    1246.000000  1246.000000
# mean     15.433788     8.536918     2.150466   60560.598256     0.145265
# std       5.001347     5.576903     1.400509   37420.456962     0.352509
# min       2.100000     1.000000     0.000080    9270.720000     0.000000
# 25%      14.000000     4.000000     1.510000   32645.055600     0.000000
# 50%      15.600000     8.000000     2.040000   52693.920000     0.000000
# 75%      15.600000     8.000000     2.330000   79773.480000     0.000000
# max     111.800000    64.000000    29.000000  324954.720000     1.000000
#
#                Ips  X_resolution  Y_resolution    Frequency
# count  1246.000000   1246.000000   1246.000000  1246.000000
# mean      0.281701   1899.609952   1073.685393     2.303387
# std       0.450009    492.666188    283.635691     0.504411
# min       0.000000   1366.000000    768.000000     0.900000
# ...

# %% [markdown]
# ## Outliers

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
sns.boxplot(x=LaptopPrice_df['Inches'])
plt.title("Boxplot")
plt.show()

# %%
LaptopPrice_df['Inches'].describe()
# Out:
# count    1246.000000
# mean       15.433788
# std         5.001347
# min         2.100000
# 25%        14.000000
# 50%        15.600000
# 75%        15.600000
# max       111.800000
# Name: Inches, dtype: float64

# %%
# Fix the outliers

Q1 = LaptopPrice_df['Inches'].quantile(0.25)
Q3 = LaptopPrice_df['Inches'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

mean_value = LaptopPrice_df['Inches'].mean()

LaptopPrice_df['Inches'] = np.where((LaptopPrice_df['Inches'] < lower_bound) | (LaptopPrice_df['Inches'] > upper_bound),mean_value,LaptopPrice_df['Inches'])
print(LaptopPrice_df['Inches'])
# Out:
# 0       13.300000
# 1       13.300000
# 2       15.600000
# 3       15.400000
# 4       13.300000
#           ...
# 1270    14.000000
# 1271    13.300000
# 1272    14.000000
# 1273    15.600000
# 1300    15.433788
# Name: Inches, Length: 1246, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
sns.boxplot(x=LaptopPrice_df['Inches'])
plt.title("Boxplot")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
sns.boxplot(x=LaptopPrice_df['Weight'])
plt.title("Boxplot")
plt.show()

# %%
LaptopPrice_df['Weight'].describe()
# Out:
# count    1246.000000
# mean        2.150466
# std         1.400509
# min         0.000080
# 25%         1.510000
# 50%         2.040000
# 75%         2.330000
# max        29.000000
# Name: Weight, dtype: float64

# %%
# Fix the outliers

Q1 = LaptopPrice_df['Weight'].quantile(0.25)
Q3 = LaptopPrice_df['Weight'].quantile(0.50)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

mean_value = LaptopPrice_df['Weight'].mean()

LaptopPrice_df['Weight'] = np.where((LaptopPrice_df['Weight'] < lower_bound) | (LaptopPrice_df['Weight'] > upper_bound),mean_value,LaptopPrice_df['Weight'])
print(LaptopPrice_df['Weight'])
# Out:
# 0       1.37
# 1       1.34
# 2       1.86
# 3       1.83
# 4       1.37
#         ...
# 1270    1.80
# 1271    1.30
# 1272    1.50
# 1273    2.19
# 1300    1.50
# Name: Weight, Length: 1246, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
sns.boxplot(x=LaptopPrice_df['Weight'])
plt.title("Boxplot")
plt.show()

# %% [markdown]
# ## Visualization and Insights

# %% [markdown]
# ### Univariate Analysis

# %%
# Histogram Plot

plt.figure(figsize=(6,5))
sns.histplot(LaptopPrice_df['Price'], kde=False, bins=10, color='red')
plt.title('Distribution of Price')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **Insights:**
# - This histogram plot shows the **spread of price.**
# - In this histogram plot **laptops are highly saled between 0 to 1 lakh.**
# - And very **low seled laptops** are between **2 lakhs to 3 lakhs.**

# %% [markdown]
# ### Bivariate Analysis

# %%
# Bar Plot

plt.figure(figsize=(8,5))
sns.barplot(x=LaptopPrice_df['Ram'].astype(int), y=LaptopPrice_df['Price'], color='blue')
plt.title('Price vs RAM')
plt.xlabel('RAM (GB)')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ### Multivariate Analysis

# %%
# Clustered Bar Plot

plt.figure(figsize=(12,6))
sns.barplot(x='Company', y='Price', hue='TypeName', data=LaptopPrice_df)
plt.title('Laptop Price by Company and Type')
plt.xlabel('Company')
plt.ylabel('Price')
plt.show()
